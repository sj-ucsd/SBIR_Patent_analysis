# %% [markdown]
# # Similarity
# This notebook uses OpenAIs LlamaIndex to find similarity between patent and SBIR abstracts

# %%
#!pip install llama-index

# %%
#import llama_index
import pandas as pd
import os
from llama_index.evaluation import SemanticSimilarityEvaluator
import import_ipynb
import spacy as sp
import json
import requests
import re
import time
from itertools import product
import io

# %% [markdown]
# ## Load data

# %%
# %%time
# read SBIR award data directly from web URL
url="https://data.www.sbir.gov/awarddatapublic/award_data.csv"
s=requests.get(url).content
sbir_df=pd.read_csv(io.StringIO(s.decode('utf-8')))
# Out:
# <timed exec>:4: DtypeWarning: Columns (10,12,13,15,38,39,40) have mixed types. Specify dtype option on import or set low_memory=False.
# CPU times: user 10.1 s, sys: 7.15 s, total: 17.3 s
# Wall time: 31 s

# %%
#sbir_df = sbir_df.sample(1000)
sbir_df = sbir_df[~sbir_df['Abstract'].isna()]
sbir_df['Abstract'] = sbir_df['Abstract'].astype(str)

# %%
# get patent data
patent_df = pd.read_json('preprocessed_files/patents.json')
patent_df = patent_df[~patent_df['abstract'].isna()]
patent_df['abstract'] = patent_df['abstract'].apply(lambda x:\
                                                    re.sub(r'\n','',x))
patent_df = patent_df.set_index('doc-number')
patent_df['abstract'] = patent_df['abstract'].astype(str)

# %% [markdown]
# ## Setup Llamaindex similarity evaulator

# %%
os.environ["OPENAI_API_KEY"] = YOUR OPEN AI KEY"

# %%
# Will use defaults. Default similarity threshold is 0.8
evaluator = SemanticSimilarityEvaluator()

# %%
# create a tuple of indicies that can be walked through
sbir_patent_tuples = list(set(list(product(sbir_df.index,patent_df.index))))
matches = [] # initialize list that contains list of sbir and patent matches

# %%
len(sbir_patent_tuples), sbir_patent_tuples[:10]
# Out:
# (755061,
#  [(20148, 20230225709),
#   (98267, 20230225591),
#   (140175, 20230225416),
#   (78831, 20230225407),
#   (193550, 20230225333),
#   (48154, 20230225609),
#   (117183, 20230225924),
#   (187914, 20230225494),
#   (123587, 20230225342),
#   (130402, 20230225792)])

# %%
# Following code is stopped after excuting 24+ hours (133k tuples processed) hence will see errors

# %%
for tple in sbir_patent_tuples:
    ref = sbir_df['Abstract'].loc[tple[0]]
    res = patent_df['abstract'].loc[tple[1]]
    if not ref or not res:
        continue
        
    result = await evaluator.aevaluate(
                    response=res,
                    reference=ref
                 )
    if result.passing:
        print(tple[0],tple[1],result.score,result.passing)
        matches.append({'sbir_id':tple[0],'patent_id':tple[1],'score':result.score})
    time.sleep(.2)
# Out:
# 66946 20230225609 0.8035576541916238 True
# 177945 20230225795 0.8072123176485497 True
# 54529 20230225600 0.8158844168103518 True
# 69226 20230225715 0.8082539626462197 True
# 160906 20230225609 0.8116168937755376 True
# 58313 20230225570 0.8187026644495451 True
# 123552 20230225644 0.8004786595568498 True
# 585 20230225653 0.8048579154474041 True
# 54529 20230225665 0.805937601090279 True
# 197666 20230225925 0.8061148332130356 True
# 87615 20230225610 0.8019542708408133 True
# 160785 20230225672 0.8076143016618101 True
# 117983 20230225328 0.8053217445187189 True
# 87615 20230225748 0.8229230086663284 True
# 127462 20230225636 0.8151068190836757 True
# 11762 20230225702 0.8020294070353361 True
# 121066 20230225331 0.8088271256418308 True
# 101988 20230225648 0.8323950158921835 True
# 53776 20230225996 0.8114534572376716 True
# 195546 20230225648 0.8007567802185377 True
# 101545 20230226135 0.8056481683656445 True
# 85308 20230225751 0.8028084117268052 True
# 141257 20230225609 0.8022134990129565 True
# 160906 20230225685 0.8120782034213775 True
# 73706 20230226135 0.8014250698641799 True
# 63528 20230225294 0.810113870719305 True
# 123033 20230225826 0.8103404782003109 True
# 26017 20230225607 0.8170362802738598 True
# 47518 20230225826 0.8042420262168972 True
# 111367 20230225660 0.8169431931070206 True
# 53776 20230225850 0.8023668110206392 True
# 125801 20230225259 0.8009907515943971 True
# 118779 20230225618 0.828466580270337 True
# 109947 20230226036 0.8022345653445202 True
# 42446 20230226088 0.8020256208344502 True
# 95241 20230226103 0.8059598354058598 True
# 136365 20230225632 0.8206298273433461 True
# 4617 20230225617 0.8084299360645089 True
# 33771 20230225636 0.8003756688980616 True
# 85308 20230225605 0.8037135446098921 True
# 188128 20230225731 0.8043952870711073 True
# 29904 20230225795 0.8047688635868231 True
# 37559 20230225430 0.814213826420604 True
# 181264 20230225633 0.8279616267177602 True
# 195277 20230225927 0.8072561797852181 True
# 101988 20230225705 0.8149400470550116 True
# 94271 20230225412 0.8142850753930015 True
# 127462 20230225712 0.8352184213426151 True
# 26017 20230225599 0.8045684051988204 True
# 16394 20230225331 0.8414141096073735 True
# 90515 20230225668 0.8074110070940749 True
# 173885 20230225741 0.8047993547702469 True
# 132142 20230225363 0.8325491224180904 True
# 85308 20230225670 0.8078904819435315 True
# 77053 20230225294 0.8114916519758893 True
# ---------------------------------------------------------------------------
# SSLWantReadError                          Traceback (most recent call last)
# File ~/anaconda3/lib/python3.9/site-packages/anyio/streams/tls.py:108, in TLSStream._call_sslobject_method(self, func, *args)
#     107 try:
# --> 108     result = func(*args)
#     109 except ssl.SSLWantReadError:
#
# File ~/anaconda3/lib/python3.9/ssl.py:888, in SSLObject.read(self, len, buffer)
#     887 else:
# --> 888     v = self._sslobj.read(len)
#     889 return v
#
# SSLWantReadError: The operation did not complete (read) (_ssl.c:2633)
#
# During handling of the above exception, another exception occurred:
#
# CancelledError                            Traceback (most recent call last)
# Cell In[15], line 7
#       4 if not ref or not res:
#       5     continue
# ----> 7 result = await evaluator.aevaluate(
#       8                 response=res,
#       9                 reference=ref
#      10              )
#      11 if result.passing:
#      12     print(tple[0],tple[1],result.score,result.passing)
#
# File ~/anaconda3/lib/python3.9/site-packages/llama_index/evaluation/semantic_similarity.py:68, in SemanticSimilarityEvaluator.aevaluate(***failed resolving arguments***)
#      66 embed_model = self._service_context.embed_model
#      67 response_embedding = await embed_model.aget_text_embedding(response)
# ---> 68 reference_embedding = await embed_model.aget_text_embedding(reference)
#      70 similarity_score = self._similarity_fn(response_embedding, reference_embedding)
#      71 passing = similarity_score >= self._similarity_threshold
#
# File ~/anaconda3/lib/python3.9/site-packages/llama_index/embeddings/base.py:222, in BaseEmbedding.aget_text_embedding(self, text)
#     218 """Async get text embedding."""
#     219 with self.callback_manager.event(
#     220     CBEventType.EMBEDDING, payload={EventPayload.SERIALIZED: self.to_dict()}
#     221 ) as event:
# --> 222     text_embedding = await self._aget_text_embedding(text)
#     224     event.on_end(
#     225         payload={
#     226             EventPayload.CHUNKS: [text],
#     227             EventPayload.EMBEDDINGS: [text_embedding],
#     228         }
#     229     )
#     231 return text_embedding
#
# File ~/anaconda3/lib/python3.9/site-packages/llama_index/embeddings/openai.py:370, in OpenAIEmbedding._aget_text_embedding(self, text)
#     368 """Asynchronously get text embedding."""
#     369 aclient = self._get_aclient()
# --> 370 return await aget_embedding(
#     371     aclient,
#     372     text,
#     373     engine=self._text_engine,
#     374     **self.additional_kwargs,
#     375 )
#
# File ~/anaconda3/lib/python3.9/site-packages/tenacity/_asyncio.py:88, in AsyncRetrying.wraps.<locals>.async_wrapped(*args, **kwargs)
#      86 @functools.wraps(fn)
#      87 async def async_wrapped(*args: t.Any, **kwargs: t.Any) -> t.Any:
# ---> 88     return await fn(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/tenacity/_asyncio.py:47, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#      45 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#      46 while True:
# ---> 47     do = self.iter(retry_state=retry_state)
#      48     if isinstance(do, DoAttempt):
#      49         try:
#
# File ~/anaconda3/lib/python3.9/site-packages/tenacity/__init__.py:314, in BaseRetrying.iter(self, retry_state)
#     312 is_explicit_retry = fut.failed and isinstance(fut.exception(), TryAgain)
#     313 if not (is_explicit_retry or self.retry(retry_state)):
# --> 314     return fut.result()
#     316 if self.after is not None:
#     317     self.after(retry_state)
#
# File ~/anaconda3/lib/python3.9/concurrent/futures/_base.py:439, in Future.result(self, timeout)
#     437     raise CancelledError()
#     438 elif self._state == FINISHED:
# --> 439     return self.__get_result()
#     441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/anaconda3/lib/python3.9/concurrent/futures/_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
# File ~/anaconda3/lib/python3.9/site-packages/tenacity/_asyncio.py:50, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#      48 if isinstance(do, DoAttempt):
#      49     try:
# ---> 50         result = await fn(*args, **kwargs)
#      51     except BaseException:  # noqa: B902
#      52         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/anaconda3/lib/python3.9/site-packages/llama_index/embeddings/openai.py:139, in aget_embedding(aclient, text, engine, **kwargs)
#     127 """Asynchronously get embedding.
#     128
#     129 NOTE: Copied from OpenAI's embedding utils:
#    (...)
#     134
#     135 """
#     136 text = text.replace("\n", " ")
#     138 return (
# --> 139     (await aclient.embeddings.create(input=[text], model=engine, **kwargs))
#     140     .data[0]
#     141     .embedding
#     142 )
#
# File ~/anaconda3/lib/python3.9/site-packages/openai/resources/embeddings.py:198, in AsyncEmbeddings.create(self, input, model, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     192         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     193             base64.b64decode(data), dtype="float32"
#     194         ).tolist()
#     196     return obj
# --> 198 return await self._post(
#     199     "/embeddings",
#     200     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     201     options=make_request_options(
#     202         extra_headers=extra_headers,
#     203         extra_query=extra_query,
#     204         extra_body=extra_body,
#     205         timeout=timeout,
#     206         post_parser=parser,
#     207     ),
#     208     cast_to=CreateEmbeddingResponse,
#     209 )
#
# File ~/anaconda3/lib/python3.9/site-packages/openai/_base_client.py:1542, in AsyncAPIClient.post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1528 async def post(
#    1529     self,
#    1530     path: str,
#    (...)
#    1537     stream_cls: type[_AsyncStreamT] | None = None,
#    1538 ) -> ResponseT | _AsyncStreamT:
#    1539     opts = FinalRequestOptions.construct(
#    1540         method="post", url=path, json_data=body, files=await async_to_httpx_files(files), **options
#    1541     )
# -> 1542     return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~/anaconda3/lib/python3.9/site-packages/openai/_base_client.py:1316, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1307 async def request(
#    1308     self,
#    1309     cast_to: Type[ResponseT],
#    (...)
#    1314     remaining_retries: Optional[int] = None,
#    1315 ) -> ResponseT | _AsyncStreamT:
# -> 1316     return await self._request(
#    1317         cast_to=cast_to,
#    1318         options=options,
#    1319         stream=stream,
#    1320         stream_cls=stream_cls,
#    1321         remaining_retries=remaining_retries,
#    1322     )
#
# File ~/anaconda3/lib/python3.9/site-packages/openai/_base_client.py:1342, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1339 response = None
#    1341 try:
# -> 1342     response = await self._client.send(
#    1343         request,
#    1344         auth=self.custom_auth,
#    1345         stream=stream or self._should_stream_response_body(request=request),
#    1346     )
#    1347     log.debug(
#    1348         'HTTP Request: %s %s "%i %s"', request.method, request.url, response.status_code, response.reason_phrase
#    1349     )
#    1350     response.raise_for_status()
#
# File ~/anaconda3/lib/python3.9/site-packages/httpx/_client.py:1617, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1609 follow_redirects = (
#    1610     self.follow_redirects
#    1611     if isinstance(follow_redirects, UseClientDefault)
#    1612     else follow_redirects
#    1613 )
#    1615 auth = self._build_request_auth(request, auth)
# -> 1617 response = await self._send_handling_auth(
#    1618     request,
#    1619     auth=auth,
#    1620     follow_redirects=follow_redirects,
#    1621     history=[],
#    1622 )
#    1623 try:
#    1624     if not stream:
#
# File ~/anaconda3/lib/python3.9/site-packages/httpx/_client.py:1645, in AsyncClient._send_handling_auth(self, request, auth, follow_redirects, history)
#    1642 request = await auth_flow.__anext__()
#    1644 while True:
# -> 1645     response = await self._send_handling_redirects(
#    1646         request,
#    1647         follow_redirects=follow_redirects,
#    1648         history=history,
#    1649     )
#    1650     try:
#    1651         try:
#
# File ~/anaconda3/lib/python3.9/site-packages/httpx/_client.py:1682, in AsyncClient._send_handling_redirects(self, request, follow_redirects, history)
#    1679 for hook in self._event_hooks["request"]:
#    1680     await hook(request)
# -> 1682 response = await self._send_single_request(request)
#    1683 try:
#    1684     for hook in self._event_hooks["response"]:
#
# File ~/anaconda3/lib/python3.9/site-packages/httpx/_client.py:1719, in AsyncClient._send_single_request(self, request)
#    1714     raise RuntimeError(
#    1715         "Attempted to send an sync request with an AsyncClient instance."
#    1716     )
#    1718 with request_context(request=request):
# -> 1719     response = await transport.handle_async_request(request)
#    1721 assert isinstance(response.stream, AsyncByteStream)
#    1722 response.request = request
#
# File ~/anaconda3/lib/python3.9/site-packages/httpx/_transports/default.py:366, in AsyncHTTPTransport.handle_async_request(self, request)
#     353 req = httpcore.Request(
#     354     method=request.method,
#     355     url=httpcore.URL(
#    (...)
#     363     extensions=request.extensions,
#     364 )
#     365 with map_httpcore_exceptions():
# --> 366     resp = await self._pool.handle_async_request(req)
#     368 assert isinstance(resp.stream, typing.AsyncIterable)
#     370 return Response(
#     371     status_code=resp.status,
#     372     headers=resp.headers,
#     373     stream=AsyncResponseStream(resp.stream),
#     374     extensions=resp.extensions,
#     375 )
#
# File ~/anaconda3/lib/python3.9/site-packages/httpcore/_async/connection_pool.py:268, in AsyncConnectionPool.handle_async_request(self, request)
#     266     with AsyncShieldCancellation():
#     267         await self.response_closed(status)
# --> 268     raise exc
#     269 else:
#     270     break
#
# File ~/anaconda3/lib/python3.9/site-packages/httpcore/_async/connection_pool.py:251, in AsyncConnectionPool.handle_async_request(self, request)
#     248         raise exc
#     250 try:
# --> 251     response = await connection.handle_async_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#     260     async with self._pool_lock:
#     261         # Maintain our position in the request queue, but reset the
#     262         # status so that the request becomes queued again.
#
# File ~/anaconda3/lib/python3.9/site-packages/httpcore/_async/connection.py:103, in AsyncHTTPConnection.handle_async_request(self, request)
#     100     elif not self._connection.is_available():
#     101         raise ConnectionNotAvailable()
# --> 103 return await self._connection.handle_async_request(request)
#
# File ~/anaconda3/lib/python3.9/site-packages/httpcore/_async/http11.py:133, in AsyncHTTP11Connection.handle_async_request(self, request)
#     131     async with Trace("response_closed", logger, request) as trace:
#     132         await self._response_closed()
# --> 133 raise exc
#
# File ~/anaconda3/lib/python3.9/site-packages/httpcore/_async/http11.py:111, in AsyncHTTP11Connection.handle_async_request(self, request)
#     101     pass
#     103 async with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = await self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#     119 return Response(
#     120     status=status,
#     121     headers=headers,
#    (...)
#     127     },
#     128 )
#
# File ~/anaconda3/lib/python3.9/site-packages/httpcore/_async/http11.py:176, in AsyncHTTP11Connection._receive_response_headers(self, request)
#     173 timeout = timeouts.get("read", None)
#     175 while True:
# --> 176     event = await self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#     178         break
#
# File ~/anaconda3/lib/python3.9/site-packages/httpcore/_async/http11.py:212, in AsyncHTTP11Connection._receive_event(self, timeout)
#     209     event = self._h11_state.next_event()
#     211 if event is h11.NEED_DATA:
# --> 212     data = await self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#     224     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/anaconda3/lib/python3.9/site-packages/httpcore/_backends/anyio.py:34, in AnyIOStream.read(self, max_bytes, timeout)
#      32 with anyio.fail_after(timeout):
#      33     try:
# ---> 34         return await self._stream.receive(max_bytes=max_bytes)
#      35     except anyio.EndOfStream:  # pragma: nocover
#      36         return b""
#
# File ~/anaconda3/lib/python3.9/site-packages/anyio/streams/tls.py:171, in TLSStream.receive(self, max_bytes)
#     170 async def receive(self, max_bytes: int = 65536) -> bytes:
# --> 171     data = await self._call_sslobject_method(self._ssl_object.read, max_bytes)
#     172     if not data:
#     173         raise EndOfStream
#
# File ~/anaconda3/lib/python3.9/site-packages/anyio/streams/tls.py:115, in TLSStream._call_sslobject_method(self, func, *args)
#     112     if self._write_bio.pending:
#     113         await self.transport_stream.send(self._write_bio.read())
# --> 115     data = await self.transport_stream.receive()
#     116 except EndOfStream:
#     117     self._read_bio.write_eof()
#
# File ~/anaconda3/lib/python3.9/site-packages/anyio/_backends/_asyncio.py:1105, in SocketStream.receive(self, max_bytes)
#    1103 if not self._protocol.read_event.is_set() and not self._transport.is_closing():
#    1104     self._transport.resume_reading()
# -> 1105     await self._protocol.read_event.wait()
#    1106     self._transport.pause_reading()
#    1108 try:
#
# File ~/anaconda3/lib/python3.9/asyncio/locks.py:226, in Event.wait(self)
#     224 self._waiters.append(fut)
#     225 try:
# --> 226     await fut
#     227     return True
#     228 finally:
#
# CancelledError:

# %%
# to find number of tuples processed, check the index of the last tuple processed
sbir_patent_tuples.index((77053, 20230225294))
# Out:
# 131306

# %%
len(sbir_patent_tuples)
# Out:
# 755061

# %%
len(matches)
# Out:
# 797

# %%
matches_df = pd.DataFrame(matches)

# %%
matches_df.to_csv('../preprocessed_files/llama_similarity.csv')

# %% [markdown]
# ## Add winning companies to the csv manually

# %%
# Manually add list of companies found via Winning companies notebook to add to SBIR and patent data
winning_list = ['Beirobotics LLC','Ultra Safe Nuclear Corporation',
'Andluca Technologies Inc.',
'FURCIFER INC.',
'Kurt J. Lesker Company',
'Nanosys'
               ]

# %%
winning_df = sbir_df[sbir_df['Company'].isin(winning_list)]
winning_df
# Out:
#                                Company  \
# 1482                   Beirobotics LLC
# 6726    Ultra Safe Nuclear Corporation
# 7726         Andluca Technologies Inc.
# 7727         Andluca Technologies Inc.
# 9317                     FURCIFER INC.
# 21889        Andluca Technologies Inc.
# 27910   Ultra Safe Nuclear Corporation
# 33678   Ultra Safe Nuclear Corporation
# 39675   Ultra Safe Nuclear Corporation
# 45077   Ultra Safe Nuclear Corporation
# 45078   Ultra Safe Nuclear Corporation
# 50314   Ultra Safe Nuclear Corporation
# 83000           Kurt J. Lesker Company
# 89585           Kurt J. Lesker Company
# 103419                         Nanosys
# 103420                         Nanosys
# 110526                         Nanosys
# 110527                         Nanosys
# 110528                         Nanosys
# 110529                         Nanosys
# 116946          Kurt J. Lesker Company
# 117982                         Nanosys
# 117983                         Nanosys
# 117984                         Nanosys
# 117985                         Nanosys
# 117986                         Nanosys
# 117987                         Nanosys
# 117988                         Nanosys
# 125543                         Nanosys
# 125544                         Nanosys
# 132731                         Nanosys
# 171725          Kurt J. Lesker Company
# 175708          Kurt J. Lesker Company
#
#                                               Award Title  \
# 1482    SBIR Phase I:Unmanned Aerial Payload Systems f...
# 6726    Affordable, Reliable, High-Performance Ceramic...
# 7726                 Self Powered Smart Glass For Windows
# 7727    SBIR Phase II: Development of a transparent, n...
# 9317    Dynamic window films for improved operational ...
# 21889   STTR Phase I: Development of a Transparent, Ne...
# 27910   Novel Technologies for Efficient NTP Reactor D...
# 33678   Novel Technologies for Efficient NTP Reactor D...
# 39675   Accident Tolerant Reactor Shutdown for NTP Sys...
# 45077   Passive Technology to Improve Criticality Cont...
# 45078   Accident Tolerant Reactor Shutdown for NTP Sys...
# 50314   Passive Technology to Improve Criticality Cont...
# 83000   SBIR Phase II:   Closed-Field Magnetron Sputte...
# 89585   SBIR PHASE I:  Closed-Field Magnetron Sputteri...
# 103419  Manufacturing Matrix-free Mass Spectrometry Ta...
# 103420  SBIR Phase II:  Large-Scale Manufacturing Proc...
# 110526  High Efficiency Nanocomposite White Light Phos...
# 110527  SBIR Phase II: High Performance Thin Film Tran...
# 110528  High Performance Transistors on Flexible Subst...
# 110529  SBIR Phase I: Large-Scale Manufacturing Proces...
# 116946           Extended Lifetime Neutron Chopper System
# 117982          SBIR Phase II:  Nanocomposite Solar Cells
# 117983  SBIR Phase II: High Performance Thin Film Tran...
# 117984       Nanowire Enhanced Substrates for Microarrays
# 117985                 Hybrid Nanocomposite Photovoltaics
# 117986  High Performance Transistors on Flexible Subst...
# 117987  SBIR Phase I:  Nanostructured MicroArray Techn...
# 117988  High Efficiency Nanocomposite White Light Phos...
# 125543                  Nanowire DNA hybridization sensor
# 125544           SBIR Phase I:  Nanocomposite Solar Cells
# 132731             BIOMOLECULE-GATED NANOWIRE FET SENSORS
# 171725  Integrated Multi-Vessel Surface Process System...
# 175708  Integrated Multi-Vessel Surface Process System...
#
#                                                Agency  \
# 1482                      National Science Foundation
# 6726                             Department of Energy
# 7726                            Department of Defense
# 7727                      National Science Foundation
# 9317                            Department of Defense
# 21889                     National Science Foundation
# 27910   National Aeronautics and Space Administration
# 33678   National Aeronautics and Space Administration
# 39675   National Aeronautics and Space Administration
# 45077   National Aeronautics and Space Administration
# 45078   National Aeronautics and Space Administration
# 50314   National Aeronautics and Space Administration
# 83000                     National Science Foundation
# 89585                     National Science Foundation
# 103419        Department of Health and Human Services
# 103420                    National Science Foundation
# 110526                           Department of Energy
# 110527                    National Science Foundation
# 110528                          Department of Defense
# 110529                    National Science Foundation
# 116946                           Department of Energy
# 117982                    National Science Foundation
# 117983                    National Science Foundation
# 117984        Department of Health and Human Services
# 117985  National Aeronautics and Space Administration
# 117986                          Department of Defense
# 117987                    National Science Foundation
# 117988                           Department of Energy
# 125543        Department of Health and Human Services
# 125544                    National Science Foundation
# 132731        Department of Health and Human Services
# 171725                          Department of Defense
# 175708                          Department of Defense
#
#                                            Branch     Phase Program  \
# 1482                                          NaN   Phase I    SBIR
# 6726                                          NaN   Phase I    SBIR
# 7726                                    Air Force   Phase I    SBIR
# 7727                                          NaN  Phase II    SBIR
# 9317                                    Air Force   Phase I    SBIR
# 21889                                         NaN   Phase I    STTR
# 27910                                         NaN  Phase II    SBIR
# 33678                                         NaN   Phase I    SBIR
# 39675                                         NaN  Phase II    SBIR
# 45077                                         NaN  Phase II    SBIR
# 45078                                         NaN   Phase I    SBIR
# 50314                                         NaN   Phase I    SBIR
# 83000                                         NaN  Phase II    SBIR
# 89585                                         NaN   Phase I    SBIR
# 103419              National Institutes of Health   Phase I    SBIR
# 103420                                        NaN  Phase II    SBIR
# 110526                                        NaN  Phase II    SBIR
# 110527                                        NaN  Phase II    SBIR
# 110528  Defense Advanced Research Projects Agency  Phase II    STTR
# 110529                                        NaN   Phase I    SBIR
# 116946                                        NaN   Phase I    STTR
# 117982                                        NaN  Phase II    SBIR
# 117983                                        NaN   Phase I    SBIR
# 117984              National Institutes of Health   Phase I    SBIR
# 117985                                        NaN   Phase I    SBIR
# 117986  Defense Advanced Research Projects Agency   Phase I    STTR
# 117987                                        NaN   Phase I    SBIR
# 117988                                        NaN   Phase I    SBIR
# 125543              National Institutes of Health   Phase I    SBIR
# 125544                                        NaN   Phase I    SBIR
# 132731              National Institutes of Health   Phase I    SBIR
# 171725                                  Air Force  Phase II    SBIR
# 175708                                  Air Force   Phase I    SBIR
#
#        Agency Tracking Number           Contract Proposal Award Date  \
# 1482                  2136680            2136680          09/15/2022
# 6726               0000266673       DE-SC0022735          06/27/2022
# 7726          FX211-CSO1-0562   FA8649-21-P-1247          04/13/2021
# 7727                  2112279            2112279          08/15/2021
# 9317          FX211-CSO1-0507   FA8649-21-P-1142          04/14/2021
# 21889                 1843743            1843743          02/01/2019
# 27910                  188423      80NSSC19C0202          08/14/2019
# 33678                  188423      80NSSC18P2173          07/27/2018
# 39675                  155532         NNX17CS02C          04/10/2017
# 45077                  154873         NNX16CM01C          05/04/2016
# 45078                  155532         NNX16CS13P          06/10/2016
# 50314                  154873         NNX15CC62P          06/17/2015
# 83000                 0740261            0923843                 NaN
# 89585                 0740261            0740261                 NaN
# 103419               GM075471  1R43GM075471-01A1                 NaN
# 103420                0512284            0620589                 NaN
# 110526             75963S04-I  DE-FG02-04ER84020                 NaN
# 110527                0340306            0450585                 NaN
# 110528             04ST1-0047   W31P4Q-05-C-R193          08/04/2005
# 110529                0512284            0512284                 NaN
# 116946             75073B04-I  DE-FG02-04ER86190                 NaN
# 117982                0318909            0422147                 NaN
# 117983                0340306            0450585                 NaN
# 117984               HG003480    1R43HG003480-01                 NaN
# 117985                 035170         NNC04CA59C          01/16/2004
# 117986             04ST1-0047   W31P4Q-04-C-RB04          09/07/2004
# 117987                0419995            0419995                 NaN
# 117988             75963S04-I  DE-FG02-04ER84020                 NaN
# 125543               CA101567    1R43CA101567-01                 NaN
# 125544                0318909            0318909                 NaN
# 132731               AI052533    1R43AI052533-01                 NaN
# 171725                  19946                NaN                 NaN
# 175708                  19946                NaN                 NaN
#
#        Contract End Date  ...              Contact Title   Contact Phone  \
# 1482          08/31/2023  ...                        NaN  (804) 898-8134
# 6726          06/26/2023  ...                        NaN  (346) 262-6222
# 7726          07/19/2021  ...                        NaN  (609) 779-2828
# 7727          07/31/2023  ...                        NaN  (832) 859-0382
# 9317          07/19/2021  ...                        NaN  (415) 867-9065
# 21889         07/31/2019  ...                        NaN  (832) 859-0382
# 27910         08/13/2021  ...                        NaN  (228) 813-6209
# 33678         02/15/2019  ...                        NaN  (740) 262-2804
# 39675         04/09/2019  ...          Business Official  (858) 342-4837
# 45077         05/03/2018  ...                        COO  (858) 750-8999
# 45078         12/09/2016  ...          Business Official  (858) 342-4837
# 50314         12/17/2015  ...          Business Official  (858) 353-9895
# 83000                NaN  ...                         BS  (412) 387-9200
# 89585                NaN  ...                         BS  (412) 387-9200
# 103419               NaN  ...                        NaN  (650) 331-2100
# 103420               NaN  ...                        NaN  (650) 331-2162
# 110526               NaN  ...                        Mr.  (650) 331-2162
# 110527               NaN  ...                         Ms  (650) 331-2106
# 110528        05/30/2007  ...  Financial Reporting Manag  (650) 331-2171
# 110529               NaN  ...                         Ms  (650) 331-2162
# 116946               NaN  ...                        Mr.  (412) 233-4200
# 117982               NaN  ...                        NaN  (650) 331-2106
# 117983               NaN  ...                         Ms  (650) 331-2106
# 117984               NaN  ...                        NaN  (650) 331-2100
# 117985        07/19/2004  ...          Business Official  (650) 331-2106
# 117986        02/01/2005  ...    Vice President, Finance  (650) 331-2114
# 117987               NaN  ...                        NaN  (650) 331-2106
# 117988               NaN  ...                        Ms.  (650) 331-2114
# 125543               NaN  ...                        NaN  (650) 331-2100
# 125544               NaN  ...                        NaN            () -
# 132731               NaN  ...                        NaN  (781) 391-9002
# 171725               NaN  ...                        NaN            () -
# 175708               NaN  ...                        NaN            () -
#
#                            Contact Email                    PI Name  \
# 1482          michael.beiro@linebird.net              Michael Beiro
# 6726                g.gustavson@usnc.com          Charles Lewinsohn
# 7726                    nick@andluca.com              Nicholas Davy
# 7727                 nickcdavy@gmail.com              Nicholas Davy
# 9317            ACUSG.Furcifer@gmail.com                  Jian Wang
# 21889                nickcdavy@gmail.com              Nicholas Davy
# 27910             james.s.hibbs@nasa.gov              Michael Eades
# 33678                   m.eades@usnc.com              Michael Eades
# 39675                 p.venneri@usnc.com              Paolo Venneri
# 45077   cjhamilton@ultrasafe-nuclear.com              Paolo Venneri
# 45078     pvenneri@ultrasafe-nuclear.com              Paolo Venneri
# 50314     fvenneri@ultrasafe-nuclear.com              Paolo Venneri
# 83000                    tomd@lesker.com          Thomas Dockstader
# 89585                    tomd@lesker.com          Thomas Dockstader
# 103419          JCUMMINGS@NANOSYSINC.COM                  R DANIELS
# 103420             jdrake@nanosysinc.com            Francesco Lemmi
# 110526              cchow@nanosysinc.com                  Jian Chen
# 110527          sguillory@nanosysinc.com               David Stumbo
# 110528            dgeorge@nanosysinc.com                Yaoling Pan
# 110529            dgeorge@nanosysinc.com            Francesco Lemmi
# 116946                  davec@lesker.com                 Gary Smith
# 117982          sguillory@nanosysinc.com                 Erik Scher
# 117983          sguillory@nanosysinc.com               David Stumbo
# 117984               CCHOW@NANOSYINC.COM                  R Daniels
# 117985          sguillory@nanosysinc.com             Andreas Meisel
# 117986           kvergura@nanosysinc.com              Yaoling . Pan
# 117987          sguillory@nanosysinc.com               Hugh Daniels
# 117988           kvergura@nanosysinc.com             Wing-Keung Woo
# 125543                               NaN                  R DANIELS
# 125544                               NaN                 Erik Scher
# 132731           KVERGURA@NANOSYSINC.COM               CHUNMING NIU
# 171725                               NaN  Michele Migliuolo, Ph.d.
# 175708                               NaN  Michele Migliuolo, Ph.d.
#
#                               PI Title        PI Phone  \
# 1482                               NaN  (804) 898-8134
# 6726                               NaN  (385) 393-0660
# 7726                               NaN  (609) 779-2828
# 7727                               NaN  (832) 859-0382
# 9317                               NaN  (510) 516-6909
# 21889                              NaN  (832) 859-0382
# 27910                              NaN  (740) 262-2804
# 33678                              NaN  (740) 262-2804
# 39675           Principal Investigator  (858) 342-4837
# 45077           Principal Investigator  (858) 342-4837
# 45078           Principal Investigator  (858) 342-4837
# 50314   Director of Space Applications  (858) 342-4837
# 83000                               BS  (412) 387-9200
# 89585                               BS  (412) 387-9200
# 103419                             NaN  (650) 331-2108
# 103420                              Dr  (650) 331-2106
# 110526                             Dr.  (650) 331-2133
# 110527                              Dr  (650) 331-2128
# 110528          Principal Investigator  (650) 331-2130
# 110529                              Dr  (650) 331-2106
# 116946                             Mr.  (412) 233-4200
# 117982                              PI  (650) 331-2106
# 117983                              Dr  (650) 331-2128
# 117984                             NaN  (650) 331-2108
# 117985          Principal Investigator  (650) 331-2100
# 117986          Principal Investigator  (650) 331-2130
# 117987                              PI  (650) 331-2106
# 117988                             Dr.  (650) 331-2160
# 125543                             NaN  (650) 331-2108
# 125544                             NaN            () -
# 132731                             NaN  (617) 669-9180
# 171725                             NaN  (412) 233-4200
# 175708                             NaN  (412) 233-4200
#
#                               PI Email                             RI Name  \
# 1482        michael.beiro@linebird.net                                 NaN
# 6726              c.lewinsohn@usnc.com                                 NaN
# 7726                  nick@andluca.com                                 NaN
# 7727               nickcdavy@gmail.com                                 NaN
# 9317          jianwang@furciferinc.com                                 NaN
# 21889              nickcdavy@gmail.com                Princeton University
# 27910                 m.eades@usnc.com                                 NaN
# 33678                 m.eades@usnc.com                                 NaN
# 39675               p.venneri@usnc.com                                 NaN
# 45077   pvenneri@ultrasafe-nuclear.com                                 NaN
# 45078   pvenneri@ultrasafe-nuclear.com                                 NaN
# 50314   pvenneri@ultrasafe-nuclear.com                                 NaN
# 83000                  tomd@lesker.com                                 NaN
# 89585                  tomd@lesker.com                                 NaN
# 103419         HDANIELS@NANOSYSINC.COM                                 NaN
# 103420           flemmi@nanosysinc.com                                 NaN
# 110526            jchen@nanosysinc.com                                 NaN
# 110527          dstumbo@nanosysinc.com                                 NaN
# 110528             ypan@nanosysinc.com                 UNIV. OF CALIFORNIA
# 110529           flemmi@nanosysinc.com                                 NaN
# 116946                garys@lesker.com         Argonne National Laboratory
# 117982        sguillory@nanosysinc.com                                 NaN
# 117983          dstumbo@nanosysinc.com                                 NaN
# 117984         HDANIELS@NANOSYSINC.COM                                 NaN
# 117985          ameisel@nanosysinc.com                                 NaN
# 117986             ypan@nanosysinc.com  University of California, Berkeley
# 117987        sguillory@nanosysinc.com                                 NaN
# 117988            wkwoo@nanosysinc.com                                 NaN
# 125543         HDANIELS@NANOSYSINC.COM                                 NaN
# 125544                             NaN                                 NaN
# 132731             CNIU@NANOSYSINC.COM                                 NaN
# 171725                             NaN                                 NaN
# 175708                             NaN                                 NaN
#
#          RI POC Name RI POC Phone
# 1482             NaN          NaN
# 6726             NaN          NaN
# 7726             NaN          NaN
# 7727             NaN          NaN
# 9317             NaN          NaN
# 21889   Yueh-Lin Loo          NaN
# 27910            NaN          NaN
# 33678            NaN          NaN
# 39675            NaN          NaN
# 45077            NaN          NaN
# 45078            NaN          NaN
# 50314            NaN          NaN
# 83000            NaN          NaN
# 89585            NaN          NaN
# 103419           NaN          NaN
# 103420           NaN          NaN
# 110526           NaN          NaN
# 110527           NaN          NaN
# 110528           NaN          NaN
# 110529           NaN          NaN
# 116946           NaN          NaN
# 117982           NaN          NaN
# 117983           NaN          NaN
# 117984           NaN          NaN
# 117985           NaN          NaN
# 117986           NaN          NaN
# 117987           NaN          NaN
# 117988           NaN          NaN
# 125543           NaN          NaN
# 125544           NaN          NaN
# 132731           NaN          NaN
# 171725           NaN          NaN
# 175708           NaN          NaN
#
# [33 rows x 41 columns]

# %%
sbir_sim_df = pd.read_csv('./preprocessed_files/sbir_df_1k_similarity.csv')

# %%
sbir_sim_df = sbir_sim_df.set_index('id')

# %%
winning_df = winning_df.rename_axis(index='id')

# %%
final_df = pd.concat([sbir_sim_df, winning_df])

# %%
final_df['Company'].value_counts()
# Out:
# Company
# Nanosys                           17
# Ultra Safe Nuclear Corporation     7
# CREARE LLC                         7
# CFD RESEARCH CORPORATION           7
# CHARLES RIVER ANALYTICS, INC.      6
#                                   ..
# Panorama Research Incorporated     1
# Hx Technologies, Inc.              1
# SNORKEL AI INC                     1
# Detectnology, Inc.                 1
# Focused Research, Inc.             1
# Name: count, Length: 722, dtype: int64

# %%
final_df.to_csv('../preprocessed_files/sbir_1k_sample.csv')

# %% [markdown]
# ## add abstract entities column

# %%
import joblib
model = joblib.load('../model/trained_tech_classifier_model.joblib')
nlp = sp.load('en_core_sci_lg')
# Out:
# /Users/sagarjogadhenu/anaconda3/lib/python3.9/site-packages/spacy/util.py:910: UserWarning: [W095] Model 'en_core_sci_lg' (0.5.3) was trained with spaCy v3.6.1 and may not be 100% compatible with the current version (3.7.2). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# /Users/sagarjogadhenu/anaconda3/lib/python3.9/site-packages/spacy/language.py:2170: FutureWarning: Possible set union at position 6328
#   deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(  # type: ignore[union-attr]

# %%
import import_ipynb
import spacy_helper_methods as sph
# Out:
# importing Jupyter notebook from spacy_helper_methods.ipynb

# %%
final_df = final_df[~final_df['Abstract'].isna()]

# %%
# %%time
final_df['abstract_entities'] = sph.extract_tech_entities(nlp, model, final_df['Abstract'])
# Out:
# CPU times: user 2min 40s, sys: 9.99 s, total: 2min 50s
# Wall time: 3min 7s
# <timed exec>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
final_df.to_csv('../preprocessed_files/sbir_1k_sample.csv')
