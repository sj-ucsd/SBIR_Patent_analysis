# %%
#!pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-0.4.21-py3-none-any.whl (508 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.6/508.6 kB 4.9 MB/s eta 0:00:0000:0100:01
# Collecting pypika>=0.48.9
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 2.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting fastapi>=0.95.2
#   Downloading fastapi-0.108.0-py3-none-any.whl (92 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 2.8 MB/s eta 0:00:00
# Collecting grpcio>=1.58.0
#   Downloading grpcio-1.60.0-cp39-cp39-macosx_10_10_universal2.whl (9.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 32.0 MB/s eta 0:00:0000:0100:01
# Collecting posthog>=2.4.0
#   Downloading posthog-3.1.0-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: importlib-resources in ./anaconda3/lib/python3.9/site-packages (from chromadb) (5.10.0)
# Collecting kubernetes>=28.1.0
#   Downloading kubernetes-28.1.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 28.0 MB/s eta 0:00:0000:01
# Requirement already satisfied: requests>=2.28 in ./anaconda3/lib/python3.9/site-packages (from chromadb) (2.31.0)
# Collecting overrides>=7.3.1
#   Downloading overrides-7.4.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: PyYAML>=6.0.0 in ./anaconda3/lib/python3.9/site-packages (from chromadb) (6.0.1)
# Collecting uvicorn[standard]>=0.18.3
#   Downloading uvicorn-0.25.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.3/60.3 kB 822.6 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: typer>=0.9.0 in ./anaconda3/lib/python3.9/site-packages (from chromadb) (0.9.0)
# Requirement already satisfied: tokenizers>=0.13.2 in ./anaconda3/lib/python3.9/site-packages (from chromadb) (0.15.0)
# Collecting pulsar-client>=3.1.0
#   Downloading pulsar_client-3.3.0-cp39-cp39-macosx_10_15_universal2.whl (10.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 13.6 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: tqdm>=4.65.0 in ./anaconda3/lib/python3.9/site-packages (from chromadb) (4.65.0)
# Collecting mmh3>=4.0.1
#   Downloading mmh3-4.0.1-cp39-cp39-macosx_10_9_x86_64.whl (34 kB)
# Collecting tenacity>=8.2.3
#   Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Collecting onnxruntime>=1.14.1
#   Downloading onnxruntime-1.16.3-cp39-cp39-macosx_10_15_x86_64.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 13.0 MB/s eta 0:00:0000:0100:01
# Collecting opentelemetry-sdk>=1.2.0
#   Downloading opentelemetry_sdk-1.22.0-py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.6/105.6 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: pydantic>=1.9 in ./anaconda3/lib/python3.9/site-packages (from chromadb) (2.5.1)
# Collecting opentelemetry-api>=1.2.0
#   Downloading opentelemetry_api-1.22.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 1.9 MB/s eta 0:00:00
# Collecting chroma-hnswlib==0.7.3
#   Downloading chroma_hnswlib-0.7.3-cp39-cp39-macosx_10_9_x86_64.whl (219 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.8/219.8 kB 7.8 MB/s eta 0:00:00
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.22.0-py3-none-any.whl (18 kB)
# Collecting bcrypt>=4.0.1
#   Downloading bcrypt-4.1.2-cp39-abi3-macosx_10_12_universal2.whl (528 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 528.5/528.5 kB 8.3 MB/s eta 0:00:0000:01
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0
#   Downloading opentelemetry_instrumentation_fastapi-0.43b0-py3-none-any.whl (11 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./anaconda3/lib/python3.9/site-packages (from chromadb) (4.8.0)
# Collecting numpy>=1.22.5
#   Using cached numpy-1.26.2-cp39-cp39-macosx_10_9_x86_64.whl (20.6 MB)
# Collecting starlette<0.33.0,>=0.29.0
#   Downloading starlette-0.32.0.post1-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.0/70.0 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: google-auth>=1.0.1 in ./anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.6.0)
# Requirement already satisfied: certifi>=14.05.14 in ./.local/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2020.12.5)
# Requirement already satisfied: urllib3<2.0,>=1.24.2 in ./.local/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.25.11)
# Requirement already satisfied: python-dateutil>=2.5.3 in ./anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: six>=1.9.0 in ./anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Collecting requests-oauthlib
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in ./anaconda3/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Collecting oauthlib>=3.2.2
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 3.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: packaging in ./anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (23.0)
# Requirement already satisfied: protobuf in ./anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: flatbuffers in ./anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: sympy in ./anaconda3/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (1.11.1)
# Requirement already satisfied: deprecated>=1.2.6 in ./anaconda3/lib/python3.9/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.13)
# Requirement already satisfied: importlib-metadata<7.0,>=6.0 in ./anaconda3/lib/python3.9/site-packages (from opentelemetry-api>=1.2.0->chromadb) (6.6.0)
# Collecting backoff<3.0.0,>=1.10.0
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting opentelemetry-proto==1.22.0
#   Downloading opentelemetry_proto-1.22.0-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 1.6 MB/s eta 0:00:00
# Collecting opentelemetry-exporter-otlp-proto-common==1.22.0
#   Downloading opentelemetry_exporter_otlp_proto_common-1.22.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in ./anaconda3/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.56.4)
# Collecting opentelemetry-util-http==0.43b0
#   Downloading opentelemetry_util_http-0.43b0-py3-none-any.whl (6.9 kB)
# Collecting opentelemetry-instrumentation-asgi==0.43b0
#   Downloading opentelemetry_instrumentation_asgi-0.43b0-py3-none-any.whl (14 kB)
# Collecting opentelemetry-instrumentation==0.43b0
#   Downloading opentelemetry_instrumentation-0.43b0-py3-none-any.whl (28 kB)
# Collecting opentelemetry-semantic-conventions==0.43b0
#   Downloading opentelemetry_semantic_conventions-0.43b0-py3-none-any.whl (36 kB)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in ./anaconda3/lib/python3.9/site-packages (from opentelemetry-instrumentation==0.43b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.12.1)
# Requirement already satisfied: setuptools>=16.0 in ./anaconda3/lib/python3.9/site-packages (from opentelemetry-instrumentation==0.43b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (66.0.0)
# Collecting asgiref~=3.0
#   Downloading asgiref-3.7.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: monotonic>=1.5 in ./anaconda3/lib/python3.9/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: pydantic-core==2.14.3 in ./anaconda3/lib/python3.9/site-packages (from pydantic>=1.9->chromadb) (2.14.3)
# Requirement already satisfied: annotated-types>=0.4.0 in ./anaconda3/lib/python3.9/site-packages (from pydantic>=1.9->chromadb) (0.6.0)
# Requirement already satisfied: idna<4,>=2.5 in ./.local/lib/python3.9/site-packages (from requests>=2.28->chromadb) (2.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./anaconda3/lib/python3.9/site-packages (from requests>=2.28->chromadb) (2.0.4)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in ./anaconda3/lib/python3.9/site-packages (from tokenizers>=0.13.2->chromadb) (0.19.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in ./anaconda3/lib/python3.9/site-packages (from typer>=0.9.0->chromadb) (8.0.4)
# Requirement already satisfied: h11>=0.8 in ./anaconda3/lib/python3.9/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0
#   Downloading uvloop-0.19.0-cp39-cp39-macosx_10_9_x86_64.whl (808 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 808.5/808.5 kB 11.8 MB/s eta 0:00:0000:01
# Collecting watchfiles>=0.13
#   Downloading watchfiles-0.21.0-cp39-cp39-macosx_10_7_x86_64.whl (428 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 428.5/428.5 kB 9.1 MB/s eta 0:00:0000:01
# Collecting websockets>=10.4
#   Downloading websockets-12.0-cp39-cp39-macosx_10_9_x86_64.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.3/121.3 kB 4.0 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting httptools>=0.5.0
#   Downloading httptools-0.6.1-cp39-cp39-macosx_10_9_x86_64.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=3.1.0 in ./anaconda3/lib/python3.9/site-packages (from importlib-resources->chromadb) (3.11.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./anaconda3/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./anaconda3/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./anaconda3/lib/python3.9/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.7.2)
# Requirement already satisfied: filelock in ./anaconda3/lib/python3.9/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in ./anaconda3/lib/python3.9/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2023.10.0)
# Requirement already satisfied: anyio<5,>=3.4.0 in ./anaconda3/lib/python3.9/site-packages (from starlette<0.33.0,>=0.29.0->fastapi>=0.95.2->chromadb) (3.5.0)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in ./anaconda3/lib/python3.9/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.2.1)
# Requirement already satisfied: sniffio>=1.1 in ./anaconda3/lib/python3.9/site-packages (from anyio<5,>=3.4.0->starlette<0.33.0,>=0.29.0->fastapi>=0.95.2->chromadb) (1.2.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in ./anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53723 sha256=3ca5238d40b8cce0668916efad1c65daa4923873b5ebcb43736f9064fa593cf1
#   Stored in directory: /Users/sagarjogadhenu/Library/Caches/pip/wheels/f7/02/64/d541eac67ec459309d1fb19e727f58ecf7ffb4a8bf42d4cfe5
# Successfully built pypika
# Installing collected packages: pypika, mmh3, websockets, uvloop, uvicorn, tenacity, python-dotenv, pulsar-client, overrides, opentelemetry-util-http, opentelemetry-semantic-conventions, opentelemetry-proto, oauthlib, numpy, humanfriendly, httptools, grpcio, bcrypt, backoff, asgiref, watchfiles, starlette, requests-oauthlib, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, coloredlogs, chroma-hnswlib, opentelemetry-sdk, opentelemetry-instrumentation, onnxruntime, kubernetes, fastapi, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.2.2
#     Uninstalling tenacity-8.2.2:
#       Successfully uninstalled tenacity-8.2.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.48.2
#     Uninstalling grpcio-1.48.2:
#       Successfully uninstalled grpcio-1.48.2
#   Attempting uninstall: bcrypt
#     Found existing installation: bcrypt 3.2.0
#     Uninstalling bcrypt-3.2.0:
#       Successfully uninstalled bcrypt-3.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# geopandas 0.9.0 requires fiona>=1.8, which is not installed.
# daal4py 2021.5.0 requires daal==2021.4.0, which is not installed.
# ydata-profiling 4.6.2 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.2 which is incompatible.
# valentine 0.1.9 requires networkx<4.0,>=2.8, but you have networkx 2.6.3 which is incompatible.
# sktime 0.17.0 requires numpy<1.25,>=1.21.0, but you have numpy 1.26.2 which is incompatible.
# sktime 0.17.0 requires pandas<2.0.0,>=1.1.0, but you have pandas 2.0.3 which is incompatible.
# scispacy 0.5.3 requires scipy<1.11, but you have scipy 1.11.4 which is incompatible.
# scispacy 0.5.3 requires spacy<3.7.0,>=3.6.0, but you have spacy 3.7.2 which is incompatible.
# pycaret 3.0.2 requires numpy<1.24,>=1.21, but you have numpy 1.26.2 which is incompatible.
# pycaret 3.0.2 requires pandas<2.0.0,>=1.3.0, but you have pandas 2.0.3 which is incompatible.
# plotly-resampler 0.8.3.2 requires pandas<2.0.0,>=1.3.5, but you have pandas 2.0.3 which is incompatible.
# numba 0.57.0 requires numpy<1.25,>=1.21, but you have numpy 1.26.2 which is incompatible.
# en-core-sci-sm 0.5.3 requires spacy<3.7.0,>=3.6.1, but you have spacy 3.7.2 which is incompatible.
# en-core-sci-scibert 0.5.3 requires spacy<3.7.0,>=3.6.1, but you have spacy 3.7.2 which is incompatible.
# en-core-sci-lg 0.5.3 requires spacy<3.7.0,>=3.6.1, but you have spacy 3.7.2 which is incompatible.
# Successfully installed asgiref-3.7.2 backoff-2.2.1 bcrypt-4.1.2 chroma-hnswlib-0.7.3 chromadb-0.4.21 coloredlogs-15.0.1 fastapi-0.108.0 grpcio-1.60.0 httptools-0.6.1 humanfriendly-10.0 kubernetes-28.1.0 mmh3-4.0.1 numpy-1.26.2 oauthlib-3.2.2 onnxruntime-1.16.3 opentelemetry-api-1.22.0 opentelemetry-exporter-otlp-proto-common-1.22.0 opentelemetry-exporter-otlp-proto-grpc-1.22.0 opentelemetry-instrumentation-0.43b0 opentelemetry-instrumentation-asgi-0.43b0 opentelemetry-instrumentation-fastapi-0.43b0 opentelemetry-proto-1.22.0 opentelemetry-sdk-1.22.0 opentelemetry-semantic-conventions-0.43b0 opentelemetry-util-http-0.43b0 overrides-7.4.0 posthog-3.1.0 pulsar-client-3.3.0 pypika-0.48.9 python-dotenv-1.0.0 requests-oauthlib-1.3.1 starlette-0.32.0.post1 tenacity-8.2.3 uvicorn-0.25.0 uvloop-0.19.0 watchfiles-0.21.0 websockets-12.0

# %%
#import chromadb
from llama_index import VectorStoreIndex
#from llama_index.vector_stores import ChromaVectorStore
from llama_index.storage.storage_context import StorageContext

# %%
from llama_index import StorageContext, load_index_from_storage
import os
import openai
# Setup OpenAI key
os.environ["OPENAI_API_KEY"] = "<YOUR OPEN AI KEY>"
openai.api_key = os.getenv("OPENAI_API_KEY")
# rebuild storage context
storage_context = StorageContext.from_defaults(persist_dir="./Downloads")

# load index
index = load_index_from_storage(storage_context)

# %%
# example queries
query_engine = index.as_query_engine()
response = query_engine.query("what are top 5 frequent technical terms")
print(response)
# Out:
# The top 5 frequent technical terms in the given context are:
# 1. 5G
# 2. Electroplating
# 3. Wireless Power Transfer (WPT)
# 4. Deep Learning
# 5. Race Detection
